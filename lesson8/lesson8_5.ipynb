# %%
###自訂function(函式)

# %%
def say_hello():

    print("Hello, World")

say_hello()
# Out:
# Hello, World

# %%
def say_hello(name):
    """這是一個簡單的函式，會印出問候語"""
    print("Hello!", name)

say_hello("Sharon")
# Out:
# Hello! Sharon
